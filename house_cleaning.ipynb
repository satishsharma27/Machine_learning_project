# %%
import pandas as pd 
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel("D:/Github all files/Machine_learning_project2.0/Data_set/independent-house.xlsx")

# %%
df.head(5)
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  Bptp Visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...               NaN
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...               NaN
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...               NaN
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# ...

# %%
df.shape
# Out:
# (1095, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1095 non-null   object
#  1   link             1095 non-null   object
#  2   society          471 non-null    object
#  3   price            968 non-null    object
#  4   rate             1054 non-null   object
#  5   area             1095 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %%
# check for duplicate

df.duplicated().sum()
# Out:
# 13

# %%
# removing duplicate

df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1082, 21)

# %%
# check for missing values

df.isnull().sum()
# Out:
# property_name        0
# link                 0
# society            619
# price              127
# rate                41
# area                 0
# areaWithType       108
# bedRoom            108
# bathroom           108
# balcony            108
# additionalRoom     504
# address             64
# noOfFloor          127
# facing             420
# agePossession      108
# nearbyLocations    182
# description         59
# furnishDetails     350
# features           420
# rating             188
# property_id         59
# dtype: int64

# %%
# Columns to drop -> property_name, link, property_id
df.drop(columns=['link', 'property_id'], inplace= True)

# %%
df.head(5)
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
# rename columns

df.rename(columns={'rate': 'price_per_sqft'}, inplace = True)

# %%
df.head(2)
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
#
#                   areaWithType     bedRoom     bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)  5 Bedrooms  4 Bathrooms  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)  5 Bedrooms  4 Bathrooms   2 Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
#
#                                      address noOfFloor      facing  \
# 0  29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors  North-East
# 1     Sector 21A Faridabad, Gurgaon, Haryana  2 Floors         NaN
#
# ...

# %%
df['society'].value_counts()
# Out:
# society
# International City by SOBHA Phase 2                  26
# Emaar MGF Marbella                                   26
# Vipul Tatvam Villa                                   25
# International City by Sobha Phase 1                  23
# Unitech Uniworld Resorts                             14
# DLF City Plots                                       11
# DLF City Plots Phase 2                               11
# Unitech Espace                                       11
# Eldeco Mansionz                                       9
# Bptp Visionnaire                                      8
# Uppal Southend4.0 ★                                   8
# Not Applicable                                        7
# Ansals Palam Vihar                                    6
# Sushant Lok 1 Builder Floors                          6
# Experion Windchants3.8 ★                              5
# DLF City Phase 1                                      5
# Vatika India Next4.1 ★                                4
# ...

# %%
df['society'].value_counts().shape
# Out:
# (188,)

# %%
df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df['society'].head(2)
# Out:
# 0    bptp visionnaire
# 1                 nan
# Name: society, dtype: object

# %%
df['society'].value_counts().shape
# Out:
# (186,)

# %%
df['society'] = df['society'].str.replace('nan','independent')

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
# price

df['price'].value_counts()
# Out:
# price
# 3.5 Crore           19
# 5.5 Crore           17
# 6.5 Crore           16
# 6 Crore             14
# 5 Crore             13
# 4.5 Crore           13
# 70 Lac              13
# 8 Crore             13
# 50 Lac              13
# 75 Lac              13
# 8.5 Crore           12
# 7 Crore             12
# 85 Lac              12
# 1.5 Crore           11
# 4 Crore             11
# 10 Crore            10
# Price on Request    10
# 45 Lac              10
# 2.25 Crore          10
# 2.5 Crore           10
# 60 Lac              10
# 90 Lac              10
# 9 Crore             10
# 9.5 Crore            9
# 12 Crore             9
# 80 Lac               9
# 1.7 Crore            9
# 2 Crore              9
# 1.1 Crore            9
# 1 Crore              8
# 6.75 Crore           8
# 11 Crore             8
# 1.6 Crore            8
# 4.6 Crore            8
# 1.3 Crore            7
# 95 Lac               7
# 12.5 Crore           7
# 3.75 Crore           7
# 1.2 Crore            7
# ...

# %%
df= df[df['price']!= 'Price on Request']

# %%
df['price'].value_counts()
# Out:
# price
# 3.5 Crore      19
# 5.5 Crore      17
# 6.5 Crore      16
# 6 Crore        14
# 50 Lac         13
# 5 Crore        13
# 4.5 Crore      13
# 75 Lac         13
# 8 Crore        13
# 70 Lac         13
# 8.5 Crore      12
# 7 Crore        12
# 85 Lac         12
# 1.5 Crore      11
# 4 Crore        11
# 60 Lac         10
# 10 Crore       10
# 45 Lac         10
# 90 Lac         10
# 2.25 Crore     10
# 2.5 Crore      10
# 9 Crore        10
# 1.1 Crore       9
# 80 Lac          9
# 9.5 Crore       9
# 2 Crore         9
# 1.7 Crore       9
# 12 Crore        9
# 11 Crore        8
# 6.75 Crore      8
# 4.6 Crore       8
# 1 Crore         8
# 1.6 Crore       8
# 65 Lac          7
# 3.75 Crore      7
# 2.1 Crore       7
# 1.3 Crore       7
# 12.5 Crore      7
# 1.2 Crore       7
# 1.35 Crore      7
# 95 Lac          7
# 40 Lac          7
# 55 Lac          7
# 3.25 Crore      6
# 7.5 Crore       6
# 2.75 Crore      6
# 3.6 Crore       6
# 1.45 Crore      6
# 6.25 Crore      6
# ...

# %%
df['price'].isnull().sum()
# Out:
# 127

# %%
df['price'].isna().sum()
# Out:
# 127

# %%
df[df['price'].isnull()]
# Out:
#                                           property_name  \
# 47        5 Bedroom House for sale in Sector 66 Gurgaon
# 60        4 Bedroom House for sale in Sector 86 Gurgaon
# 61    8 Bedroom House for sale in B1 Block Sector 57...
# 62              6 Bedroom House for sale in DLF Phase 1
# 63      6 Bedroom House for sale in Sushant Lok Phase 3
# 64      6 Bedroom House for sale in Sushant Lok Phase 3
# 65              4 Bedroom House for sale in DLF Phase 4
# 66          8 Bedroom House for sale in Uppals Southend
# 67          6 Bedroom House for sale in Uppals Southend
# 68        4 Bedroom House for sale in Sector 48 Gurgaon
# 69              4 Bedroom House for sale in Malibu Town
# 70        5 Bedroom House for sale in Sector 33 Gurgaon
# 71              5 Bedroom House for sale in DLF Phase 1
# 72             3 Bedroom House for sale in South City 1
# 75       5 Bedroom House for sale in Sector 109 Gurgaon
# 76       4 Bedroom House for sale in Sector 109 Gurgaon
# ...

# %%
df[df['price'].isna()]
# Out:
#                                           property_name  \
# 47        5 Bedroom House for sale in Sector 66 Gurgaon
# 60        4 Bedroom House for sale in Sector 86 Gurgaon
# 61    8 Bedroom House for sale in B1 Block Sector 57...
# 62              6 Bedroom House for sale in DLF Phase 1
# 63      6 Bedroom House for sale in Sushant Lok Phase 3
# 64      6 Bedroom House for sale in Sushant Lok Phase 3
# 65              4 Bedroom House for sale in DLF Phase 4
# 66          8 Bedroom House for sale in Uppals Southend
# 67          6 Bedroom House for sale in Uppals Southend
# 68        4 Bedroom House for sale in Sector 48 Gurgaon
# 69              4 Bedroom House for sale in Malibu Town
# 70        5 Bedroom House for sale in Sector 33 Gurgaon
# 71              5 Bedroom House for sale in DLF Phase 1
# 72             3 Bedroom House for sale in South City 1
# 75       5 Bedroom House for sale in Sector 109 Gurgaon
# 76       4 Bedroom House for sale in Sector 109 Gurgaon
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1072 entries, 0 to 1094
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1072 non-null   object
#  1   society          1072 non-null   object
#  2   price            945 non-null    object
#  3   price_per_sqft   1041 non-null   object
#  4   area             1072 non-null   object
#  5   areaWithType     964 non-null    object
#  6   bedRoom          964 non-null    object
#  7   bathroom         964 non-null    object
#  8   balcony          964 non-null    object
#  9   additionalRoom   578 non-null    object
#  10  address          1008 non-null   object
#  11  noOfFloor        945 non-null    object
#  12  facing           661 non-null    object
#  13  agePossession    964 non-null    object
#  14  nearbyLocations  897 non-null    object
#  15  description      1013 non-null   object
#  16  furnishDetails   729 non-null    object
# ...

# %%
def price_treament(x):
    if type(x)== float:
        return x
    else:
        if x[1]== 'Lac':
            return round(float(x[0])/100,2)
        else:
            return round(float(x[0]),2)

# %%
dfnew = df.copy()

# %%
dfnew['price'] = dfnew['price'].str.split(' ').apply(price_treament)

# %%
dfnew.sample(5)
# Out:
#                                         property_name  \
# 721    5 Bedroom House for sale in Sector 109 Gurgaon
# 385            3 Bedroom House for sale in Hira Nagar
# 234       6 Bedroom House for sale in Saraswati Vihar
# 540        2 Bedroom House for sale in New Jyoti Park
# 1    5 Bedroom House for sale in Sector 21A Faridabad
#
#                                  society  price    price_per_sqft  \
# 721  international city by sobha phase 2   9.50   ₹ 26,389/sq.ft.
# 385                          independent   1.05    ₹ 9,722/sq.ft.
# 234                 housing board colony   3.50   ₹ 25,926/sq.ft.
# 540                          independent   1.15   ₹ 12,777/sq.ft.
# 1                            independent   5.70  ₹ 105,751/sq.ft.
#
#                           area                        areaWithType  \
# 721      (334 sq.m.) Plot Area         Plot area 400(334.45 sq.m.)
# 385  (100 sq.m.) Built-up Area  Built Up area: 1080 (100.34 sq.m.)
# ...

# %%
# price_per_sqft

df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 22,222/sq.ft.     14
# ₹ 11,111/sq.ft.     12
# ₹ 33,333/sq.ft.     11
# ₹ 10,000/sq.ft.     10
# ₹ 13,333/sq.ft.      7
# ₹ 37,037/sq.ft.      7
# ₹ 26,667/sq.ft.      6
# ₹ 26,235/sq.ft.      6
# ₹ 30,556/sq.ft.      6
# ₹ 31,481/sq.ft.      6
# ₹ 8,000/sq.ft.       6
# ₹ 9,444/sq.ft.       5
# ₹ 5,000/sq.ft.       5
# ₹ 8,889/sq.ft.       5
# ₹ 23,333/sq.ft.      5
# ₹ 23,148/sq.ft.      5
# ₹ 11,100/sq.ft.      5
# ₹ 32,407/sq.ft.      5
# ₹ 6,944/sq.ft.       4
# ₹ 15,625/sq.ft.      4
# ₹ 24,691/sq.ft.      4
# ₹ 34,722/sq.ft.      4
# ₹ 21,605/sq.ft.      4
# ₹ 25,000/sq.ft.      4
# ₹ 9,722/sq.ft.       4
# ₹ 35,000/sq.ft.      4
# ₹ 18,889/sq.ft.      4
# ₹ 27,778/sq.ft.      4
# ₹ 33,951/sq.ft.      3
# ₹ 12,000/sq.ft.      3
# ₹ 23,457/sq.ft.      3
# ₹ 6,666/sq.ft.       3
# ₹ 17,037/sq.ft.      3
# ₹ 8,444/sq.ft.       3
# ₹ 13,889/sq.ft.      3
# ₹ 44,444/sq.ft.      3
# ₹ 14,815/sq.ft.      3
# ₹ 11,250/sq.ft.      3
# ₹ 10,556/sq.ft.      3
# ...

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype('float')

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price  price_per_sqft                   area  \
# 0  5.25 Crore         20115.0  (242 sq.m.) Plot Area
# 1   5.7 Crore        105751.0   (50 sq.m.) Plot Area
# 2   2.1 Crore         38251.0   (51 sq.m.) Plot Area
# 3     5 Crore         43066.0  (108 sq.m.) Plot Area
# 4     3 Crore         53763.0   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)   5 Bedrooms   4 Bathrooms   2 Balconies
# ...

# %%
# bedrooms
df['bedRoom'].value_counts()
# Out:
# bedRoom
# 4 Bedrooms     232
# 5 Bedrooms     194
# 3 Bedrooms     146
# 2 Bedrooms      88
# 6 Bedrooms      81
# 9 Bedrooms      45
# 1 Bedroom       38
# 8 Bedrooms      33
# 7 Bedrooms      31
# 12 Bedrooms     28
# 10 Bedrooms     21
# 16 Bedrooms     12
# 13 Bedrooms      4
# 18 Bedrooms      2
# 19 Bedrooms      2
# 11 Bedrooms      2
# 20 Bedrooms      1
# 21 Bedrooms      1
# 36 Bedrooms      1
# 34 Bedrooms      1
# 14 Bedrooms      1
# Name: count, dtype: int64

# %%
df[df['bedRoom'].isnull()]
# Out:
#                                           property_name  \
# 60        4 Bedroom House for sale in Sector 86 Gurgaon
# 61    8 Bedroom House for sale in B1 Block Sector 57...
# 62              6 Bedroom House for sale in DLF Phase 1
# 63      6 Bedroom House for sale in Sushant Lok Phase 3
# 64      6 Bedroom House for sale in Sushant Lok Phase 3
# 65              4 Bedroom House for sale in DLF Phase 4
# 66          8 Bedroom House for sale in Uppals Southend
# 67          6 Bedroom House for sale in Uppals Southend
# 68        4 Bedroom House for sale in Sector 48 Gurgaon
# 69              4 Bedroom House for sale in Malibu Town
# 70        5 Bedroom House for sale in Sector 33 Gurgaon
# 71              5 Bedroom House for sale in DLF Phase 1
# 72             3 Bedroom House for sale in South City 1
# 75       5 Bedroom House for sale in Sector 109 Gurgaon
# 76       4 Bedroom House for sale in Sector 109 Gurgaon
# 79        5 Bedroom House for sale in Sector 66 Gurgaon
# ...

# %%
df = df[~df['bedRoom'].isnull()]

# %%
df.shape
# Out:
# (964, 19)

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_9280\1468100853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
df.head(5)
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price  price_per_sqft                   area  \
# 0  5.25 Crore         20115.0  (242 sq.m.) Plot Area
# 1   5.7 Crore        105751.0   (50 sq.m.) Plot Area
# 2   2.1 Crore         38251.0   (51 sq.m.) Plot Area
# 3     5 Crore         43066.0  (108 sq.m.) Plot Area
# 4     3 Crore         53763.0   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)        5   4 Bathrooms  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)        5   4 Bathrooms   2 Balconies
# ...

# %%
# bathroom
df['bathroom'].value_counts()
# Out:
# bathroom
# 4 Bathrooms     228
# 3 Bathrooms     165
# 5 Bathrooms     137
# 2 Bathrooms     114
# 6 Bathrooms      82
# 1 Bathroom       65
# 9 Bathrooms      42
# 7 Bathrooms      39
# 8 Bathrooms      28
# 12 Bathrooms     22
# 10 Bathrooms     11
# 16 Bathrooms      8
# 18 Bathrooms      4
# 13 Bathrooms      4
# 11 Bathrooms      4
# 20 Bathrooms      3
# 17 Bathrooms      3
# 14 Bathrooms      2
# 21 Bathrooms      1
# 36 Bathrooms      1
# 34 Bathrooms      1
# Name: count, dtype: int64

# %%
df['bathroom'].isnull().sum()
# Out:
# 0

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_9280\1455936528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df.head(5)
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price  price_per_sqft                   area  \
# 0  5.25 Crore         20115.0  (242 sq.m.) Plot Area
# 1   5.7 Crore        105751.0   (50 sq.m.) Plot Area
# 2   2.1 Crore         38251.0   (51 sq.m.) Plot Area
# 3     5 Crore         43066.0  (108 sq.m.) Plot Area
# 4     3 Crore         53763.0   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)        5         4   2 Balconies
# ...

# %%
# balcony
df['balcony'].value_counts()
# Out:
# balcony
# 3+ Balconies    365
# 2 Balconies     220
# 3 Balconies     159
# No Balcony      115
# 1 Balcony       105
# Name: count, dtype: int64

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No','0')
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_9280\3830839697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price  price_per_sqft                   area  \
# 0  5.25 Crore         20115.0  (242 sq.m.) Plot Area
# 1   5.7 Crore        105751.0   (50 sq.m.) Plot Area
# 2   2.1 Crore         38251.0   (51 sq.m.) Plot Area
# 3     5 Crore         43066.0  (108 sq.m.) Plot Area
# 4     3 Crore         53763.0   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# ...

# %%
# additionalRoom
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# Servant Room                                     81
# Pooja Room,Study Room,Servant Room,Store Room    60
# Others                                           58
# Pooja Room                                       38
# Pooja Room,Study Room,Servant Room               33
# Pooja Room,Study Room,Servant Room,Others        32
# Store Room                                       31
# Pooja Room,Servant Room                          24
# Study Room                                       19
# Study Room,Servant Room                          19
# Servant Room,Store Room                          15
# Pooja Room,Study Room                            11
# Pooja Room,Store Room                            11
# Pooja Room,Others                                11
# Servant Room,Pooja Room                           8
# Servant Room,Others                               8
# Pooja Room,Store Room,Study Room,Servant Room     8
# Pooja Room,Servant Room,Store Room                7
# ...

# %%
df['additionalRoom'].fillna('not available',inplace=True)
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_9280\1615843200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_9280\4218856625.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df.head(5)
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price  price_per_sqft                   area  \
# 0  5.25 Crore         20115.0  (242 sq.m.) Plot Area
# 1   5.7 Crore        105751.0   (50 sq.m.) Plot Area
# 2   2.1 Crore         38251.0   (51 sq.m.) Plot Area
# 3     5 Crore         43066.0  (108 sq.m.) Plot Area
# 4     3 Crore         53763.0   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# ...

# %%
# floors
df['noOfFloor'].value_counts()
# Out:
# noOfFloor
# 3 Floors     304
# 2 Floors     288
# 1 Floors     181
# 4 Floors     136
# 5 Floors       9
# 0 Floors       6
# 14 Floors      3
# 6 Floors       3
# 11 Floors      2
# 12 Floors      2
# 10 Floors      2
# 16 Floors      1
# 51 Floors      1
# 41 Floors      1
# 27 Floors      1
# 20 Floors      1
# 13 Floors      1
# 21 Floors      1
# 02 Floors      1
# 33 Floors      1
# Name: count, dtype: int64

# %%
df['noOfFloor'].isnull().sum()
# Out:
# 19

# %%
df['noOfFloor'] = df['noOfFloor'].str.split(' ').str.get(0)
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_9280\1520918849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['noOfFloor'] = df['noOfFloor'].str.split(' ').str.get(0)

# %%
df.head(5)
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price  price_per_sqft                   area  \
# 0  5.25 Crore         20115.0  (242 sq.m.) Plot Area
# 1   5.7 Crore        105751.0   (50 sq.m.) Plot Area
# 2   2.1 Crore         38251.0   (51 sq.m.) Plot Area
# 3     5 Crore         43066.0  (108 sq.m.) Plot Area
# 4     3 Crore         53763.0   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# ...

# %%
df.rename(columns={'noOfFloor':'floorNum'},inplace=True)
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_9280\3235111005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'noOfFloor':'floorNum'},inplace=True)

# %%
df.head(5)
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price  price_per_sqft                   area  \
# 0  5.25 Crore         20115.0  (242 sq.m.) Plot Area
# 1   5.7 Crore        105751.0   (50 sq.m.) Plot Area
# 2   2.1 Crore         38251.0   (51 sq.m.) Plot Area
# 3     5 Crore         43066.0  (108 sq.m.) Plot Area
# 4     3 Crore         53763.0   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# ...

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_9280\3692945726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['facing'].fillna('NA',inplace=True)

# %%
df.to_csv('houseworktill28092024.csv')

# %%
df = pd.read_csv('houseworktill28092024.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0                                     property_name  \
# 0           0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1           1  5 Bedroom House for sale in Sector 21A Faridabad
# 2           2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3           3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4           4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#             society       price  price_per_sqft                   area  \
# 0  bptp visionnaire  5.25 Crore         20115.0  (242 sq.m.) Plot Area
# 1       independent   5.7 Crore        105751.0   (50 sq.m.) Plot Area
# 2       independent   2.1 Crore         38251.0   (51 sq.m.) Plot Area
# 3       independent     5 Crore         43066.0  (108 sq.m.) Plot Area
# 4       independent     3 Crore         53763.0   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# ...

# %%
df.insert(loc=1,column='property_type', value = 'house')

# %%
df.head(5)
# Out:
#    Unnamed: 0 property_type                                     property_name  \
# 0           0         house    5 Bedroom House for sale in Sector 70A Gurgaon
# 1           1         house  5 Bedroom House for sale in Sector 21A Faridabad
# 2           2         house  10 Bedroom House for sale in Sushant Lok Phase 1
# 3           3         house    21 Bedroom House for sale in Sector 54 Gurgaon
# 4           4         house  12 Bedroom House for sale in Sushant Lok Phase 1
#
#             society       price  price_per_sqft                   area  \
# 0  bptp visionnaire  5.25 Crore         20115.0  (242 sq.m.) Plot Area
# 1       independent   5.7 Crore        105751.0   (50 sq.m.) Plot Area
# 2       independent   2.1 Crore         38251.0   (51 sq.m.) Plot Area
# 3       independent     5 Crore         43066.0  (108 sq.m.) Plot Area
# 4       independent     3 Crore         53763.0   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 964 entries, 0 to 963
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       964 non-null    int64
#  1   property_type    964 non-null    object
#  2   property_name    964 non-null    object
#  3   society          964 non-null    object
#  4   price            945 non-null    object
#  5   price_per_sqft   945 non-null    float64
#  6   area             964 non-null    object
#  7   areaWithType     964 non-null    object
#  8   bedRoom          964 non-null    int64
#  9   bathroom         964 non-null    int64
#  10  balcony          964 non-null    object
#  11  additionalRoom   964 non-null    object
#  12  address          959 non-null    object
#  13  floorNum         945 non-null    float64
#  14  facing           661 non-null    object
#  15  agePossession    964 non-null    object
# ...

# %%
def price_treament(x):
    if type(x)== float:
        return x
    else:
        if x[1]== 'Lac':
            return round(float(x[0])/100,2)
        else:
            return round(float(x[0]),2)

# %%
df['price'] = df['price'].str.split(' ').apply(price_treament)

# %%
df.head(5)
# Out:
#    Unnamed: 0 property_type                                     property_name  \
# 0           0         house    5 Bedroom House for sale in Sector 70A Gurgaon
# 1           1         house  5 Bedroom House for sale in Sector 21A Faridabad
# 2           2         house  10 Bedroom House for sale in Sushant Lok Phase 1
# 3           3         house    21 Bedroom House for sale in Sector 54 Gurgaon
# 4           4         house  12 Bedroom House for sale in Sushant Lok Phase 1
#
#             society  price  price_per_sqft                   area  \
# 0  bptp visionnaire   5.25         20115.0  (242 sq.m.) Plot Area
# 1       independent   5.70        105751.0   (50 sq.m.) Plot Area
# 2       independent   2.10         38251.0   (51 sq.m.) Plot Area
# 3       independent   5.00         43066.0  (108 sq.m.) Plot Area
# 4       independent   3.00         53763.0   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 964 entries, 0 to 963
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       964 non-null    int64
#  1   property_type    964 non-null    object
#  2   property_name    964 non-null    object
#  3   society          964 non-null    object
#  4   price            945 non-null    float64
#  5   price_per_sqft   945 non-null    float64
#  6   area             964 non-null    object
#  7   areaWithType     964 non-null    object
#  8   bedRoom          964 non-null    int64
#  9   bathroom         964 non-null    int64
#  10  balcony          964 non-null    object
#  11  additionalRoom   964 non-null    object
#  12  address          959 non-null    object
#  13  floorNum         945 non-null    float64
#  14  facing           661 non-null    object
#  15  agePossession    964 non-null    object
# ...

# %%
df['area'] = round((df['price']*10000000)/df['price_per_sqft'])

# %%
df.head(5)
# Out:
#    Unnamed: 0 property_type                                     property_name  \
# 0           0         house    5 Bedroom House for sale in Sector 70A Gurgaon
# 1           1         house  5 Bedroom House for sale in Sector 21A Faridabad
# 2           2         house  10 Bedroom House for sale in Sushant Lok Phase 1
# 3           3         house    21 Bedroom House for sale in Sector 54 Gurgaon
# 4           4         house  12 Bedroom House for sale in Sushant Lok Phase 1
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
# 1       independent   5.70        105751.0   539.0
# 2       independent   2.10         38251.0   549.0
# 3       independent   5.00         43066.0  1161.0
# 4       independent   3.00         53763.0   558.0
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# ...

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df.head(2)
# Out:
#   property_type                                     property_name  \
# 0         house    5 Bedroom House for sale in Sector 70A Gurgaon
# 1         house  5 Bedroom House for sale in Sector 21A Faridabad
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
# 1       independent   5.70        105751.0   539.0
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
#
#                        additionalRoom  \
# 0                        servant room
# 1  store room,pooja room,servant room
#
#                                      address  floorNum      facing  \
# 0  29b, Sector 70A Gurgaon, Gurgaon, Haryana       3.0  North-East
# 1     Sector 21A Faridabad, Gurgaon, Haryana       2.0         NaN
#
#       agePossession                                    nearbyLocations  \
# ...

# %%
df.shape
# Out:
# (964, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 964 entries, 0 to 963
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_type    964 non-null    object
#  1   property_name    964 non-null    object
#  2   society          964 non-null    object
#  3   price            945 non-null    float64
#  4   price_per_sqft   945 non-null    float64
#  5   area             945 non-null    float64
#  6   areaWithType     964 non-null    object
#  7   bedRoom          964 non-null    int64
#  8   bathroom         964 non-null    int64
#  9   balcony          964 non-null    object
#  10  additionalRoom   964 non-null    object
#  11  address          959 non-null    object
#  12  floorNum         945 non-null    float64
#  13  facing           661 non-null    object
#  14  agePossession    964 non-null    object
#  15  nearbyLocations  848 non-null    object
# ...

# %%
df.to_csv('house_cleaned.csv',index=False)
